# %% [markdown]
# Import the data :
#
# mongoimport --type csv -d energy_data -c renewables --headerline --drop MER_T10_01.csv

# %%
from pymongo import MongoClient
from pprint import pprint
import folium
from folium import plugins
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
from IPython.display import display

# %%
midwest_geojson = 'midwest.json'
gdf = gpd.read_file(midwest_geojson)

# %%
# Calculate the mean of the geometries to set the center manually
center_lat = gdf.geometry.centroid.y.mean()
center_lon = gdf.geometry.centroid.x.mean()

# Create a folium.Map object with the manually set center
m = folium.Map(location=[center_lat, center_lon], zoom_start=5)

# Display the map
m
# Out:
# C:\Users\hespr\AppData\Local\Temp\ipykernel_24120\2615464939.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf.geometry.centroid.y.mean()
# C:\Users\hespr\AppData\Local\Temp\ipykernel_24120\2615464939.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf.geometry.centroid.x.mean()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ede1b3d0e56d64c9c2152afa8e9912a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ede1b3d0e56d64c9c2152afa8e9912a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ede1b3d0e56d64c9c2152afa8e9912a9 = L.map(
#                 &quot;map_ede1b3d0e56d64c9c2152afa8e9912a9&quot;,
#                 {
#                     center: [42.659764761279206, -93.93847597076089],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4a7176fa2cfb353c85d7a02a2459b6e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a4a7176fa2cfb353c85d7a02a2459b6e.addTo(map_ede1b3d0e56d64c9c2152afa8e9912a9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
table_10 = pd.read_csv('MER_T10_01.csv')
biomass_data = pd.read_csv('biomass_energy_consump.csv')
geothermal_data = pd.read_csv('geothermal_energy_consump.csv')
hydro_data = pd.read_csv('hydropower_energy_consump.csv')
solar_data = pd.read_csv('solar_energy_consump.csv')
wind_data = pd.read_csv('wind_energy_consump.csv')

biomass_data = biomass_data.drop(columns=biomass_data.columns[23:61])
geothermal_data = geothermal_data.drop(columns=geothermal_data.columns[23:61])
hydro_data = hydro_data.drop(columns=hydro_data.columns[23:61])
solar_data = solar_data.drop(columns=solar_data.columns[23:61])
wind_data = wind_data.drop(columns=wind_data.columns[23:61])

# %%
# table_10.head()
biomass_data.head()
# geothermal_data.head()
# hydro_data.head()
# solar_data.head()
# wind_data.head()
# Out:
#       Biomass_2000 Biomass_2001 Biomass_2002 Biomass_2003 Biomass_2004  \
# State
# AK           2,069        3,445        3,540        3,494        3,783
# AL         203,782      166,334      163,686      156,371      186,726
# AR          83,466       66,837       72,972       80,406       75,933
# AZ          13,376       10,389        9,319        9,573        9,704
# CA         164,105      164,137      171,500      205,815      228,444
#
#       Biomass_2005 Biomass_2006 Biomass_2007 Biomass_2008 Biomass_2009  ...  \
# State                                                                   ...
# AK           1,197        1,249        1,426        1,447        2,770  ...
# AL         178,417      194,853      188,449      177,209      151,859  ...
# AR          81,477       84,758       89,239       79,760       89,205  ...
# AZ          25,335       25,421       29,420       36,719       29,481  ...
# CA         226,206      220,116      225,983      230,785      238,181  ...
#
#       Biomass_2012 Biomass_2013 Biomass_2014 Biomass_2015 Biomass_2016  \
# State
# AK           2,298        3,660        6,494        7,530        9,181
# AL         194,992      213,553      203,628      192,270      194,485
# AR         103,550      106,124      105,604       95,088       93,707
# AZ          27,209       27,187       33,300       35,397       37,709
# CA         296,354      343,657      349,289      344,065      349,253
#
#       Biomass_2017 Biomass_2018 Biomass_2019 Biomass_2020 Biomass_2021
# State
# AK           7,802        8,231        7,668        8,687        8,503
# AL         198,072      196,226      193,284      187,599      196,574
# AR          93,283       94,536       92,332       74,385       72,036
# AZ          37,953       40,107       40,871       35,235       37,237
# CA         357,861      357,070      405,324      400,214      467,144
#
# [5 rows x 22 columns]

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'energy_data', 'epa', 'fruits_db', 'gardenDB', 'local', 'marketing', 'met', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the database to a variable name
db = mongo['energy_data']
db_st = mongo['state_data']

# %%
# review the collections in thedatabase
print(db.list_collection_names())
# Out:
# ['renewables']

# %%
# review a document in the collection
print(db.renewables.find_one())
# Out:
# {'_id': ObjectId('65b46a42db1d32e044e87536'), 'MSN': 'WDPRBUS', 'YYYYMM': 194913, 'Value': 1549.262, 'Column_Order': 1, 'Description': 'Wood Energy Production', 'Unit': 'Trillion Btu'}

# %%
# assign the collection to a variable
renewables = db['renewables']
state_prod_v_consum = db_st['state_prod_v_consum']

# %%
# import folium
# import pandas as pd

# # Generate random data for demonstration
# midwest_data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Renewable Energy Consumption (MW)': [500, 300, 700, 400, 450, 600, 350, 250, 200, 550, 150, 500]
# }

# # Create a DataFrame from the data
# df = pd.DataFrame(midwest_data)

# # Create a Folium map centered around the Midwest
# midwest_map = folium.Map(location=[41.5, -90], zoom_start=6)

# # Add a choropleth layer to represent renewable energy consumption
# folium.Choropleth(
#     geo_data='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json',
#     name='choropleth',
#     data=df,
#     columns=['State', 'Renewable Energy Consumption (MW)'],
#     key_on='feature.properties.name',
#     fill_color='YlGn',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     legend_name='Renewable Energy Consumption (MW)'
# ).add_to(midwest_map)

# # Add popup markers with data for each state
# for i, row in df.iterrows():
#     folium.Marker(
#         location=[41.5, -90],
#         popup=f"{row['State']}: {row['Renewable Energy Consumption (MW)']} MW",
#         icon=folium.Icon(color='blue')
#     ).add_to(midwest_map)

# # Display the map
# # midwest_map.save('midwest_renewable_energy_map.html')
# midwest_map


# # Generate random data for demonstration
# midwest_data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Renewable Energy Consumption (MW)': [500, 300, 700, 400, 450, 600, 350, 250, 200, 550, 150, 500]
# }

# # Create a DataFrame from the data
# df = pd.DataFrame(midwest_data)

# # Load GeoJSON data for US states
# geojson_url = 'http://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json'

# # Create a Folium map centered around the Midwest
# midwest_map = folium.Map(location=[41.5, -90], zoom_start=6)

# midwest_states = {
#     'Illinois': 'Springfield',
#     'Indiana': 'Indianapolis',
#     'Iowa': 'Des Moines',
#     'Kansas': 'Topeka',
#     'Michigan': 'Lansing',
#     'Minnesota': 'St. Paul',
#     'Missouri': 'Jefferson City',
#     'Nebraska': 'Lincoln',
#     'North Dakota': 'Bismarck',
#     'Ohio': 'Columbus',
#     'South Dakota': 'Pierre',
#     'Wisconsin': 'Madison'
# }



# # Add markers for each state capital
# for state, data in capitals_coordinates.items():
#     lat, lon = data['latitude'], data['longitude']
#     folium.Marker([lat, lon], popup=f"{data['capital']}, {state}").add_to(midwest_map)


# # Add a choropleth layer to represent renewable energy consumption
# folium.Choropleth(
#     geo_data=geojson_url,
#     name='choropleth',
#     data=df,
#     columns=['State', 'Renewable Energy Consumption (MW)'],
#     key_on='feature.properties.name',
#     fill_color='YlGn',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     legend_name='Renewable Energy Consumption (MW)'
# ).add_to(midwest_map)

# # # Add popup markers with data for each state
# # for i, row in df.iterrows():
# #     folium.Marker(
# #         location=None,  # You should add the actual location here
# #         popup=f"{row['State']}: {row['Renewable Energy Consumption (MW)']} MW",
# #         icon=folium.Icon(color='blue')
# #     ).add_to(midwest_map)

# # Display the map
# midwest_map

# # Sample data - you need to replace this with your actual data
# data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Biomass': [100, 120, 80, 150, 200, 90, 110, 130, 170, 190, 120, 150],
#     'Hydropower': [50, 60, 40, 70, 80, 45, 55, 65, 85, 95, 60, 75],
#     'Geothermal': [30, 35, 25, 40, 50, 30, 35, 40, 45, 50, 35, 40],
#     'Solar': [20, 25, 15, 30, 40, 20, 25, 30, 35, 40, 25, 30],
#     'Wind': [150, 180, 120, 200, 250, 130, 160, 180, 220, 240, 170, 200],
# }

# df = pd.DataFrame(data)

# # Create a map centered around the Midwest
# midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# # Add data to the map
# for _, row in df.iterrows():
#     state = row['State']
#     biomass = row['Biomass']
#     hydropower = row['Hydropower']
#     geothermal = row['Geothermal']
#     solar = row['Solar']
#     wind = row['Wind']

#     if state == 'Illinois':
#         location = [39.799999, -89.650002]
#     elif state == 'Indiana':
#         location = [39.791000, -86.148003]
#     elif state == 'Iowa':
#         location = [41.619549, -93.598022]
#     elif state == 'Kansas':
#         location = [39.056198, -95.695312]
#     elif state == 'Michigan':
#         location = [42.732536, -84.555534]
#     elif state == 'Minnesota':
#         location = [44.949642, -93.093124]
#     elif state == 'Missouri':
#         location = [38.579575, -92.174782]
#     elif state == 'Nebraska':
#         location = [40.806862, -96.681679]
#     elif state == 'North Dakota':
#         location = [46.825905, -100.778275]
#     elif state == 'Ohio':
#         location = [39.983334, -82.983330]
#     elif state == 'South Dakota':
#         location = [44.3675, -100.3352]
#     elif state == 'Wisconsin':
#         location = [43.073051, -89.401230]
        
#     # Create a popup message with the data
#     popup_text = f"""
#     State: {state}
#     Biomass: {biomass}
#     Hydropower: {hydropower}
#     Geothermal: {geothermal}
#     Solar: {solar}
#     Wind: {wind}
#     """

#     # Add a marker for each state
#     folium.Marker(
#         location=location,  # Replace with actual latitude and longitude for each state
#         popup=popup_text,
#         icon=folium.Icon(color='green'),
#     ).add_to(midwest_map)

# # Display the map
# midwest_map
# import folium
# from folium import plugins
# import pandas as pd

# # Sample data - you need to replace this with your actual data
# data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2009, 2010, 2015, 2019, 2020, 2021],
#     'Biomass': [100, 120, 80, 150, 200, 90, 110, 130, 170, 190, 120, 150],
#     'Hydropower': [50, 60, 40, 70, 80, 45, 55, 65, 85, 95, 60, 75],
#     'Geothermal': [30, 35, 25, 40, 50, 30, 35, 40, 45, 50, 35, 40],
#     'Solar': [20, 25, 15, 30, 40, 20, 25, 30, 35, 40, 25, 30],
#     'Wind': [150, 180, 120, 200, 250, 130, 160, 180, 220, 240, 170, 200],
# }

# df = pd.DataFrame(data)

# # Create a map centered around the Midwest
# midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# # Add data to the map
# for _, row in df.iterrows():
#     state = row['State']
#     year = row['Year']
#     biomass = row['Biomass']
#     hydropower = row['Hydropower']
#     geothermal = row['Geothermal']
#     solar = row['Solar']
#     wind = row['Wind']

#     if state == 'Illinois':
#         location = [39.799999, -89.650002]
#     elif state == 'Indiana':
#         location = [39.791000, -86.148003]
#     elif state == 'Iowa':
#         location = [41.619549, -93.598022]
#     elif state == 'Kansas':
#         location = [39.056198, -95.695312]
#     elif state == 'Michigan':
#         location = [42.732536, -84.555534]
#     elif state == 'Minnesota':
#         location = [44.949642, -93.093124]
#     elif state == 'Missouri':
#         location = [38.579575, -92.174782]
#     elif state == 'Nebraska':
#         location = [40.806862, -96.681679]
#     elif state == 'North Dakota':
#         location = [46.825905, -100.778275]
#     elif state == 'Ohio':
#         location = [39.983334, -82.983330]
#     elif state == 'South Dakota':
#         location = [44.3675, -100.3352]
#     elif state == 'Wisconsin':
#         location = [43.073051, -89.401230]
        
#     # Create a popup message with the data
#     popup_text = f"""
#     State: {state}
#     Year: {year}
#     Biomass: {biomass}
#     Hydropower: {hydropower}
#     Geothermal: {geothermal}
#     Solar: {solar}
#     Wind: {wind}
#     """

#     # Add a marker for each state
#     folium.Marker(
#         location=location,
#         popup=popup_text,
#         icon=folium.Icon(color='green'),
#     ).add_to(midwest_map)

# # Add a dropdown menu for selecting years
# dropdown = plugins.Dropdown(
#     options=[str(year) for year in df['Year'].unique()],
#     # Add event handler to update the map when a year is selected
#     callback=lambda value, map_obj: update_map(value, df, map_obj),
#     position='topright',
# )

# # Add the dropdown to the map
# dropdown.add_to(midwest_map)

# # Display the map
# midwest_map

# def update_map(selected_year, df, map_obj):
#     # Clear existing markers
#     for marker in map_obj.get_children():
#         if isinstance(marker, folium.Marker):
#             marker.add_to(None)

#     # Filter the DataFrame for the selected year
#     selected_data = df[df['Year'] == int(selected_year)]

#     # Add markers for the selected year
#     for _, row in selected_data.iterrows():
#         state = row['State']
#         biomass = row['Biomass']
#         hydropower = row['Hydropower']
#         geothermal = row['Geothermal']
#         solar = row['Solar']
#         wind = row['Wind']

#         # Get the location for each state
#         location = get_location(state)

#         # Create a popup message with the data
#         popup_text = f"""
#         State: {state}
#         Year: {selected_year}
#         Biomass: {biomass}
#         Hydropower: {hydropower}
#         Geothermal: {geothermal}
#         Solar: {solar}
#         Wind: {wind}
#         """

#         # Add a marker for each state
#         folium.Marker(
#             location=location,
#             popup=popup_text,
#             icon=folium.Icon(color='green'),
#         ).add_to(map_obj)

# # Function to get the location for each state
# def get_location(state):
#     # Add latitude and longitude for each state
#     locations = {
#         'Illinois': [39.799999, -89.650002],
#         'Indiana': [39.791000, -86.148003],
#         'Iowa': [41.619549, -93.598022],
#         'Kansas': [39.056198, -95.695312],
#         'Michigan': [42.732536, -84.555534],
#         'Minnesota': [44.949642, -93.093124],
#         'Missouri': [38.579575, -92.174782],
#         'Nebraska': [40.806862, -96.681679],
#         'North Dakota': [46.825905, -100.778275],
#         'Ohio': [39.983334, -82.983330],
#         'South Dakota': [44.3675, -100.3352],
#         'Wisconsin': [43.073051, -89.401230],
#     }
#     return locations.get(state, [0, 0])  # Default to [0, 0] if the state is not found

# import folium
# from ipywidgets import Dropdown
# from IPython.display import display
# import pandas as pd

# # Sample data - you need to replace this with your actual data
# data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2009, 2010, 2015, 2019, 2020, 2021],
#     'Biomass': [100, 120, 80, 150, 200, 90, 110, 130, 170, 190, 120, 150],
#     'Hydropower': [50, 60, 40, 70, 80, 45, 55, 65, 85, 95, 60, 75],
#     'Geothermal': [30, 35, 25, 40, 50, 30, 35, 40, 45, 50, 35, 40],
#     'Solar': [20, 25, 15, 30, 40, 20, 25, 30, 35, 40, 25, 30],
#     'Wind': [150, 180, 120, 200, 250, 130, 160, 180, 220, 240, 170, 200],
# }

# df = pd.DataFrame(data)

# # Create a map centered around the Midwest
# midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# # Add data to the map
# for _, row in df.iterrows():
#     state = row['State']
#     year = row['Year']
#     biomass = row['Biomass']
#     hydropower = row['Hydropower']
#     geothermal = row['Geothermal']
#     solar = row['Solar']
#     wind = row['Wind']

#     if state == 'Illinois':
#         location = [39.799999, -89.650002]
#     elif state == 'Indiana':
#         location = [39.791000, -86.148003]
#     elif state == 'Iowa':
#         location = [41.619549, -93.598022]
#     elif state == 'Kansas':
#         location = [39.056198, -95.695312]
#     elif state == 'Michigan':
#         location = [42.732536, -84.555534]
#     elif state == 'Minnesota':
#         location = [44.949642, -93.093124]
#     elif state == 'Missouri':
#         location = [38.579575, -92.174782]
#     elif state == 'Nebraska':
#         location = [40.806862, -96.681679]
#     elif state == 'North Dakota':
#         location = [46.825905, -100.778275]
#     elif state == 'Ohio':
#         location = [39.983334, -82.983330]
#     elif state == 'South Dakota':
#         location = [44.3675, -100.3352]
#     elif state == 'Wisconsin':
#         location = [43.073051, -89.401230]
        
#     # Create a popup message with the data
#     popup_text = f"""
#     State: {state}
#     Year: {year}
#     Biomass: {biomass}
#     Hydropower: {hydropower}
#     Geothermal: {geothermal}
#     Solar: {solar}
#     Wind: {wind}
#     """

#     # Add a marker for each state
#     folium.Marker(
#         location=location,
#         popup=popup_text,
#         icon=folium.Icon(color='green'),
#     ).add_to(midwest_map)

# # Create a dropdown widget for selecting years
# year_dropdown = Dropdown(options=df['Year'].unique(), value=df['Year'].min(), description='Year:')
# display(year_dropdown)

# # Function to update the map based on the selected year
# def update_map(change):
#     selected_year = change['new']
    
#     # Clear existing markers
#     for marker in midwest_map.get_children():
#         if isinstance(marker, folium.Marker):
#             marker.add_to(None)

#     # Filter the DataFrame for the selected year
#     selected_data = df[df['Year'] == selected_year]

#     # Add markers for the selected year
#     for _, row in selected_data.iterrows():
#         state = row['State']
#         biomass = row['Biomass']
#         hydropower = row['Hydropower']
#         geothermal = row['Geothermal']
#         solar = row['Solar']
#         wind = row['Wind']

#         # Get the location for each state
#         location = get_location(state)

#         # Create a popup message with the data
#         popup_text = f"""
#         State: {state}
#         Year: {selected_year}
#         Biomass: {biomass}
#         Hydropower: {hydropower}
#         Geothermal: {geothermal}
#         Solar: {solar}
#         Wind: {wind}
#         """

#         # Add a marker for each state
#         folium.Marker(
#             location=location,
#             popup=popup_text,
#             icon=folium.Icon(color='green'),
#         ).add_to(midwest_map)

# # Connect the function to the dropdown's value change event
# year_dropdown.observe(update_map, names='value')

# # Display the map
# midwest_map

import folium
from ipywidgets import Dropdown
from IPython.display import display
import pandas as pd

# Sample data - you need to replace this with your actual data
data = {
    'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2009, 2010, 2015, 2019, 2020, 2021],
    'Biomass': [100, 120, 80, 150, 200, 90, 110, 130, 170, 190, 120, 150],
    'Hydropower': [50, 60, 40, 70, 80, 45, 55, 65, 85, 95, 60, 75],
    'Geothermal': [30, 35, 25, 40, 50, 30, 35, 40, 45, 50, 35, 40],
    'Solar': [20, 25, 15, 30, 40, 20, 25, 30, 35, 40, 25, 30],
    'Wind': [150, 180, 120, 200, 250, 130, 160, 180, 220, 240, 170, 200],
}

df = pd.DataFrame(data)

# Create a map centered around the Midwest
midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# Dictionary to store markers
markers_dict = {}

# Function to add markers for a given year
def add_markers_for_year(selected_year):
    # Clear existing markers
    clear_markers()

    # Filter the DataFrame for the selected year
    selected_data = df[df['Year'] == selected_year]

    # Add markers for the selected year
    for _, row in selected_data.iterrows():
        state = row['State']
        biomass = row['Biomass']
        hydropower = row['Hydropower']
        geothermal = row['Geothermal']
        solar = row['Solar']
        wind = row['Wind']

        # Get the location for each state
        location = get_location(state)

        # Create a popup message with the data
        popup_text = f"""
        State: {state}
        Year: {selected_year}
        Biomass: {biomass}
        Hydropower: {hydropower}
        Geothermal: {geothermal}
        Solar: {solar}
        Wind: {wind}
        """

        # Add a marker for each state
        markers_dict[state] = folium.Marker(
            location=location,
            popup=popup_text,
            icon=folium.Icon(color='green'),
        )
        markers_dict[state].add_to(midwest_map)

# Function to clear existing markers
def clear_markers():
    for marker in markers_dict.values():
        marker.add_to(None)

# Create a dropdown widget for selecting years
year_dropdown = Dropdown(options=df['Year'].unique(), value=df['Year'].min(), description='Year:')
display(year_dropdown)

# Function to update the map based on the selected year
def update_map(change):
    selected_year = change['new']
    add_markers_for_year(selected_year)

# Connect the function to the dropdown's value change event
year_dropdown.observe(update_map, names='value')

# Display the map
midwest_map
# Out:
# Dropdown(description='Year:', options=(2000, 2001, 2002, 2003, 2004, 2005, 2009, 2010, 2015, 2019, 2020, 2021)…
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3e448b8f1bf7dbcb81ceaaf91391114 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3e448b8f1bf7dbcb81ceaaf91391114&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3e448b8f1bf7dbcb81ceaaf91391114 = L.map(
#                 &quot;map_c3e448b8f1bf7dbcb81ceaaf91391114&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c24bb0d948a7f0349533d6c2767130a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c24bb0d948a7f0349533d6c2767130a.addTo(map_c3e448b8f1bf7dbcb81ceaaf91391114);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File ~\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:643, in Widget.set_state(self, sync_data)
#     638         self._send(msg, buffers=echo_buffers)
#     640 # The order of these context managers is important. Properties must
#     641 # be locked when the hold_trait_notification context manager is
#     642 # released and notifications are fired.
# --> 643 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     644     for name in sync_data:
#     645         if name in self.keys:
#
# File ~\anaconda3\Lib\contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1498, in HasTraits.hold_trait_notifications(self)
#    1496 for changes in cache.values():
#    1497     for change in changes:
# -> 1498         self.notify_change(change)
#
# File ~\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:694, in Widget.notify_change(self, change)
#     691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
# --> 694 super().notify_change(change)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1513, in HasTraits.notify_change(self, change)
#    1511 def notify_change(self, change):
#    1512     """Notify observers of a change event"""
# -> 1513     return self._notify_observers(change)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1560, in HasTraits._notify_observers(self, event)
#    1557 elif isinstance(c, EventHandler) and c.name is not None:
#    1558     c = getattr(self, c.name)
# -> 1560 c(event)
#
# File ~\anaconda3\Lib\site-packages\ipywidgets\widgets\widget_selection.py:236, in _Selection._propagate_index(self, change)
#     234     self.label = label
#     235 if self.value is not value:
# --> 236     self.value = value
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:729, in TraitType.__set__(self, obj, value)
#     727     raise TraitError('The "%s" trait is read-only.' % self.name)
#     728 else:
# --> 729     self.set(obj, value)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:718, in TraitType.set(self, obj, value)
#     714     silent = False
#     715 if silent is not True:
#     716     # we explicitly compare silent to True just in case the equality
#     717     # comparison above returns something other than True/False
# --> 718     obj._notify_trait(self.name, old_value, new_value)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1501, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1500 def _notify_trait(self, name, old_value, new_value):
# -> 1501     self.notify_change(
#    1502         Bunch(
#    1503             name=name,
#    1504             old=old_value,
#    1505             new=new_value,
#    1506             owner=self,
#    1507             type="change",
#    1508         )
#    1509     )
#
# File ~\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:694, in Widget.notify_change(self, change)
#     691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
# --> 694 super().notify_change(change)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1513, in HasTraits.notify_change(self, change)
#    1511 def notify_change(self, change):
#    1512     """Notify observers of a change event"""
# -> 1513     return self._notify_observers(change)
#
# File ~\anaconda3\Lib\site-packages\traitlets\traitlets.py:1560, in HasTraits._notify_observers(self, event)
#    1557 elif isinstance(c, EventHandler) and c.name is not None:
#    1558     c = getattr(self, c.name)
# -> 1560 c(event)
#
# Cell In[122], line 518, in update_map(change)
#     516 def update_map(change):
#     517     selected_year = change['new']
# --> 518     add_markers_for_year(selected_year)
#
# Cell In[122], line 485, in add_markers_for_year(selected_year)
#     482 wind = row['Wind']
#     484 # Get the location for each state
# --> 485 location = get_location(state)
#     487 # Create a popup message with the data
#     488 popup_text = f"""
#     489 State: {state}
#     490 Year: {selected_year}
#    (...)
#     495 Wind: {wind}
#     496 """
#
# NameError: name 'get_location' is not defined

# %%
import folium
from ipywidgets import Dropdown
from IPython.display import display
import pandas as pd

# # Sample data - you need to replace this with your actual data
# data = {
#     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#     'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2009, 2010, 2015, 2019, 2020, 2021],
#     'Biomass': [100, 120, 80, 150, 200, 90, 110, 130, 170, 190, 120, 150],
#     'Hydropower': [50, 60, 40, 70, 80, 45, 55, 65, 85, 95, 60, 75],
#     'Geothermal': [30, 35, 25, 40, 50, 30, 35, 40, 45, 50, 35, 40],
#     'Solar': [20, 25, 15, 30, 40, 20, 25, 30, 35, 40, 25, 30],
#     'Wind': [150, 180, 120, 200, 250, 130, 160, 180, 220, 240, 170, 200],
# }

# df = pd.DataFrame(data)

# biomass_data = pd.read_csv('biomass_energy_consump.csv')
# geothermal_data = pd.read_csv('geothermal_energy_consump.csv')
# hydro_data = pd.read_csv('hydropower_energy_consump.csv')
# solar_data = pd.read_csv('solar_energy_consump.csv')
# wind_data = pd.read_csv('wind_energy_consump.csv')

df = biomass_data.set_index('State')
df['Geothermal'] = geothermal_data.set_index('State')['Geothermal']
df['Hydropower'] = hydro_data.set_index('State')['Hydropower']
df['Solar'] = solar_data.set_index('State')['Solar']
df['Wind'] = wind_data.set_index('State')['Wind']

# Create a map centered around the Midwest
midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# Dictionary to store markers
markers_dict = {}

# Function to add markers for a given year
def add_markers_for_year(selected_year):
    # Clear existing markers
    clear_markers()

    # Filter the DataFrame for the selected year
    selected_data = df[df['Year'] == selected_year]

    # Add markers for the selected year
    for _, row in selected_data.iterrows():
        state = row['State']
        biomass = row['Biomass']
        hydropower = row['Hydropower']
        geothermal = row['Geothermal']
        solar = row['Solar']
        wind = row['Wind']

        # Get the location for each state
        location = get_location(state)

        # Create a popup message with the data
        popup_text = f"""
        State: {state}
        Year: {selected_year}
        Biomass: {biomass}
        Hydropower: {hydropower}
        Geothermal: {geothermal}
        Solar: {solar}
        Wind: {wind}
        """

        # Add a marker for each state
        markers_dict[state] = folium.Marker(
            location=location,
            popup=popup_text,
            icon=folium.Icon(color='green'),
        )
        markers_dict[state].add_to(midwest_map)

# Function to clear existing markers
def clear_markers():
    for marker in markers_dict.values():
        marker.add_to(None)

# Function to get the location for a given state
def get_location(state):
    # Replace with the actual latitude and longitude for each state
    if state == 'Illinois':
        return [39.799999, -89.650002]
    elif state == 'Indiana':
        return [39.791000, -86.148003]
    elif state == 'Iowa':
        return [41.619549, -93.598022]
    elif state == 'Kansas':
        return [39.056198, -95.695312]
    elif state == 'Michigan':
        return [42.732536, -84.555534]
    elif state == 'Minnesota':
        return [44.949642, -93.093124]
    elif state == 'Missouri':
        return [38.579575, -92.174782]
    elif state == 'Nebraska':
        return [40.806862, -96.681679]
    elif state == 'North Dakota':
        return [46.825905, -100.778275]
    elif state == 'Ohio':
        return [39.983334, -82.983330]
    elif state == 'South Dakota':
        return [44.3675, -100.3352]
    elif state == 'Wisconsin':
        return [43.073051, -89.401230]

# Create a dropdown widget for selecting years
year_dropdown = Dropdown(options=df['Year'].unique(), value=df['Year'].min(), description='Year:')
display(year_dropdown)

# Function to update the map based on the selected year
def update_map(change):
    selected_year = change['new']
    add_markers_for_year(selected_year)

# Connect the function to the dropdown's value change event
year_dropdown.observe(update_map, names='value')

# Display the map
midwest_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Geothermal'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 26
#       6 # # Sample data - you need to replace this with your actual data
#       7 # data = {
#       8 #     'State': ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin'],
#    (...)
#      22 # solar_data = pd.read_csv('solar_energy_consump.csv')
#      23 # wind_data = pd.read_csv('wind_energy_consump.csv')
#      25 df = biomass_data.set_index('State')
# ---> 26 df['Geothermal'] = geothermal_data.set_index('State')['Geothermal']
#      27 df['Hydropower'] = hydro_data.set_index('State')['Hydropower']
#      28 df['Solar'] = solar_data.set_index('State')['Solar']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Geothermal'

# %%
import folium
from ipywidgets import Dropdown
from IPython.display import display
import pandas as pd

# Function to load data from CSV file
def load_energy_data(file_path, energy_type):
    data = pd.read_csv(file_path)
    data.set_index('State', inplace=True)
    data.rename(columns=lambda x: f"{energy_type}_{x}", inplace=True)
    return data

# Load data from each CSV file
biomass_data = load_energy_data('biomass_energy_consump.csv', 'Biomass')
geothermal_data = load_energy_data('geothermal_energy_consump.csv', 'Geothermal')
hydro_data = load_energy_data('hydropower_energy_consump.csv', 'Hydropower')
solar_data = load_energy_data('solar_energy_consump.csv', 'Solar')
wind_data = load_energy_data('wind_energy_consump.csv', 'Wind')

# Dropped columns that were causing issues
biomass_data = biomass_data.drop(columns=biomass_data.columns[22:61])
geothermal_data = geothermal_data.drop(columns=geothermal_data.columns[22:61])
hydro_data = hydro_data.drop(columns=hydro_data.columns[22:61])
solar_data = solar_data.drop(columns=solar_data.columns[22:61])
wind_data = wind_data.drop(columns=wind_data.columns[22:61])

# Consolidated  the data into a single dataframe
df = pd.concat([biomass_data, geothermal_data, hydro_data, solar_data, wind_data], axis=1)


state_mapping = {
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'NE': 'Nebraska',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'SD': 'South Dakota',
    'WI': 'Wisconsin'
}

# Create a map centered around the Midwest
midwest_map = folium.Map(location=[41.8781, -87.6298], zoom_start=5)

# Dictionary to store markers
markers_dict = {}
selected_year = 2000
def add_markers_for_year_and_energy(selected_year, energy_type):
    # Clear existing markers
    clear_markers()
    print(selected_year)
    print(energy_type)
    
    def handle_click(**kwargs):
        lat, lon = kwargs['location']
        state = get_state_from_location(lat, lon)
        selected_year = year_dropdown.value
        selected_energy = energy_dropdown.value
        display_state_data(state, selected_year, selected_energy)

    # Function to get the state from the clicked location
    def get_state_from_location(lat, lon):
    # Replace this with the logic to determine the state based on latitude and longitude
    # For simplicity, let's assume you have a function that returns the state name
        return "Illinois"  # Replace with the actual logic

    # Function to display the state data
    def display_state_data(state, selected_year, selected_energy):
        clear_markers()  # Clear existing markers

        # Get the location for each state
        location = get_location(full_state_name)

        # Create a popup message with the data for the selected energy type
        popup_text = f"""
        State: {full_state_name}
        Year: {selected_year}
        {energy_type}: {row[energy_type + '_' + selected_year]}
        """
        # Add a marker for each state
        markers_dict[state] = folium.Marker(
            location=location,
            popup=popup_text,
            icon=folium.Icon(color='green'),
        )
        markers_dict[state].add_to(midwest_map)

# Function to clear existing markers
def clear_markers():
    for marker in markers_dict.values():
        marker.add_to(None)

# Function to get the location for a given state
def get_location(state):
    # Replace with the actual latitude and longitude for each state
    if state == 'Illinois':
        return [39.799999, -89.650002]
    elif state == 'Indiana':
        return [39.791000, -86.148003]
    elif state == 'Iowa':
        return [41.619549, -93.598022]
    elif state == 'Kansas':
        return [39.056198, -95.695312]
    elif state == 'Michigan':
        return [42.732536, -84.555534]
    elif state == 'Minnesota':
        return [44.949642, -93.093124]
    elif state == 'Missouri':
        return [38.579575, -92.174782]
    elif state == 'Nebraska':
        return [40.806862, -96.681679]
    elif state == 'North Dakota':
        return [46.825905, -100.778275]
    elif state == 'Ohio':
        return [39.983334, -82.983330]
    elif state == 'South Dakota':
        return [44.3675, -100.3352]
    elif state == 'Wisconsin':
        return [43.073051, -89.401230]


# Function to update the map based on the selected year and energy type
def update_map(change):
    print(change)
#     selected_year = year_dropdown.value
    selected_energy = energy_dropdown.value
    add_markers_for_year_and_energy(selected_year, selected_energy)

# Create a dropdown widget for selecting energy types
energy_dropdown = Dropdown(options=df.columns[1:], value=df.columns[1], description='Energy Type:')
display(energy_dropdown)

# Connect the function to the dropdowns' value change events
# year_dropdown.observe(update_map, names='value')
energy_dropdown.observe(update_map, names='value')

# Create a dropdown widget for selecting years
# year_dropdown = Dropdown(options=df.columns, value=df.columns.min(), description='Year:')
# display(year_dropdown)

# Add a ClickForMarker feature to the map
click_for_marker = folium.ClickForMarker(popup='Click for marker')
click_for_marker.add_to(midwest_map)

# Display the map
# midwest_map
# Out:
# Dropdown(description='Energy Type:', options=('Biomass_2001', 'Biomass_2002', 'Biomass_2003', 'Biomass_2004', …
